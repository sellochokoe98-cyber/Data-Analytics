# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\sello\Downloads\UN_SDG_dashboard_data.csv")
df.head()
# Out:
#   Country Code ISO3               Country  2021 SDG Index Rank  \
# 0               AFG           Afghanistan                137.0
# 1               AGO                Angola                154.0
# 2               ALB               Albania                 64.0
# 3               AND               Andorra                  NaN
# 4               ARE  United Arab Emirates                 71.0
#
#    2021 SDG Index Score  Regional Score (0-100) Regions used for the SDR  \
# 0                  53.9                    71.4      E. Europe & C. Asia
# 1                  50.3                    51.9                   Africa
# 2                  71.0                    71.4      E. Europe & C. Asia
# 3                   NaN                    71.4      E. Europe & C. Asia
# 4                  70.2                    67.1                     MENA
#
#   Population in 2020   Goal 1     Goal 2     Goal 3  ...     Goal 8  \
# 0         38,928,341      NaN  50.131000  37.098357  ...  37.753167
# ...

# %%
df.head()
# Out:
#   Country Code ISO3               Country  2021 SDG Index Rank  \
# 0               AFG           Afghanistan                137.0
# 1               AGO                Angola                154.0
# 2               ALB               Albania                 64.0
# 3               AND               Andorra                  NaN
# 4               ARE  United Arab Emirates                 71.0
#
#    2021 SDG Index Score  Regional Score (0-100) Regions used for the SDR  \
# 0                  53.9                    71.4      E. Europe & C. Asia
# 1                  50.3                    51.9                   Africa
# 2                  71.0                    71.4      E. Europe & C. Asia
# 3                   NaN                    71.4      E. Europe & C. Asia
# 4                  70.2                    67.1                     MENA
#
#   Population in 2020   Goal 1     Goal 2     Goal 3  ...     Goal 8  \
# 0         38,928,341      NaN  50.131000  37.098357  ...  37.753167
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country Code ISO3         205 non-null    str
#  1   Country                   205 non-null    str
#  2   2021 SDG Index Rank       165 non-null    float64
#  3   2021 SDG Index Score      177 non-null    float64
#  4   Regional Score (0-100)    193 non-null    float64
#  5   Regions used for the SDR  193 non-null    str
#  6   Population in 2020        193 non-null    str
#  7   Goal 1                    166 non-null    float64
#  8   Goal 2                    177 non-null    float64
#  9   Goal 3                    177 non-null    float64
#  10  Goal 4                    176 non-null    float64
#  11  Goal 5                    177 non-null    float64
#  12  Goal 6                    177 non-null    float64
#  13  Goal 7                    177 non-null    float64
# ...

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df.isnull().sum()
# Out:
# Country_Code_ISO3            0
# Country                      0
# 2021_SDG_Index_Rank         40
# 2021_SDG_Index_Score        28
# Regional_Score_(0-100)      12
# Regions_used_for_the_SDR    12
# Population_in_2020          12
# Goal_1                      39
# Goal_2                      28
# Goal_3                      28
# Goal_4                      29
# Goal_5                      28
# Goal_6                      28
# Goal_7                      28
# Goal_8                      28
# Goal_9                      28
# Goal_10                     43
# Goal_11                     28
# Goal_12                     28
# Goal_13                     28
# Goal_14                     69
# Goal_15                     28
# Goal_16                     28
# Goal_17                     28
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.sort_values("2021_SDG_Index_Score", ascending=False).head()
# Out:
#     Country_Code_ISO3  Country  2021_SDG_Index_Rank  2021_SDG_Index_Score  \
# 56                FIN  Finland                  1.0                  85.9
# 163               SWE   Sweden                  2.0                  85.6
# 47                DNK  Denmark                  3.0                  84.9
# 44                DEU  Germany                  4.0                  82.5
# 12                BEL  Belgium                  5.0                  82.2
#
#      Regional_Score_(0-100) Regions_used_for_the_SDR Population_in_2020  \
# 56                     77.2                     OECD          5,540,718
# 163                    77.2                     OECD         10,099,270
# 47                     77.2                     OECD          5,792,203
# 44                     77.2                     OECD         83,783,945
# 12                     77.2                     OECD         11,589,616
#
#       Goal_1     Goal_2     Goal_3  ...     Goal_8     Goal_9  Goal_10  \
# ...

# %%
df.sort_values("2021_SDG_Index_Score").head()
# Out:
#     Country_Code_ISO3           Country  2021_SDG_Index_Rank  \
# 141               PRK  Korea, Dem. Rep.                  0.0
# 38                COM           Comoros                  0.0
# 107               MCO            Monaco                  0.0
# 131               NRU             Nauru                  0.0
# 138               PLW             Palau                  0.0
#
#      2021_SDG_Index_Score  Regional_Score_(0-100) Regions_used_for_the_SDR  \
# 141                   0.0                    65.7        East & South Asia
# 38                    0.0                    51.9                   Africa
# 107                   0.0                    71.4      E. Europe & C. Asia
# 131                   0.0                    50.1                  Oceania
# 138                   0.0                    50.1                  Oceania
#
#     Population_in_2020  Goal_1  Goal_2  Goal_3  ...  Goal_8  Goal_9  Goal_10  \
# ...

# %%
df["2021_SDG_Index_Score"].mean()
# Out:
# np.float64(57.52585365853659)

# %%
df.groupby("Regions_used_for_the_SDR")["2021_SDG_Index_Score"].mean()
# Out:
# Regions_used_for_the_SDR
# 0                      64.541667
# Africa                 48.495918
# E. Europe & C. Asia    61.451852
# East & South Asia      60.495238
# LAC                    51.353333
# MENA                   62.641176
# OECD                   79.024324
# Oceania                15.250000
# Name: 2021_SDG_Index_Score, dtype: float64

# %%
import matplotlib.pyplot as plt

top = df.sort_values("2021_SDG_Index_Score", ascending=False).head(10)

plt.bar(top["Country"], top["2021_SDG_Index_Score"])
plt.xticks(rotation=45)
plt.show()
