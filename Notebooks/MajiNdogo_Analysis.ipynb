# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df = pd.read_excel(r"C:\Users\sello\Downloads\Md_water_services_data.xlsx")
df.head()
# Out:
#       source_id                date  \
# 0  KiRu28935224 2021-01-04 09:17:00
# 1  AkLu01628224 2021-01-04 09:53:00
# 2  HaZa21742224 2021-01-04 10:37:00
# 3  HaRu19725224 2021-01-04 11:04:00
# 4  SoRu35703224 2021-01-04 11:29:00
#
#                                          description  pollutant_ppm  \
# 0                          Bacteria: Giardia Lamblia       0.000000
# 1                                  Bacteria: E. coli       0.000000
# 2  Inorganic contaminants: Zinc, Zinc, Lead, Cadmium       2.715000
# 3                                              Clean       0.028859
# 4                                  Bacteria: E. coli       0.000000
#
#    biological                   results
# 0  495.898000  Contaminated: Biological
# 1    6.096080  Contaminated: Biological
# 2    0.000000    Contaminated: Chemical
# 3    0.000096                     Clean
# 4   22.500900  Contaminated: Biological

# %%
print ("How many total water services are in the dataset?") 
total_services = len(df)
total_services
# Out:
# How many total water services are in the dataset?
# 17383

# %%
print ("How many records have a pollutant measurement?")
records_with_pollutant = df['pollutant_ppm'].notnull().sum()
records_with_pollutant
# Out:
# How many records have a pollutant measurement?
# np.int64(17383)

# %%
records_with_bio = df['biological'].notnull().sum()
print("How many records have a biological measurement?", records_with_bio)
# Out:
# How many records have a biological measurement? 17383

# %%
print ("Average pollutant value (ppm)")
average_pollutant = df['pollutant_ppm'].mean()
average_pollutant
# Out:
# Average pollutant value (ppm)
# np.float64(2.2844185359086464)

# %%
print ("Highest and lowest pollutant readings")
max_pollutant = df['pollutant_ppm'].max()
min_pollutant = df['pollutant_ppm'].min()
max_pollutant, min_pollutant
# Out:
# Highest and lowest pollutant readings
# (np.float64(9.99901), np.float64(0.0))

# %%
print ("Count of each result type") 
result_counts = df['results'].value_counts()
result_counts
# Out:
# Count of each result type
# results
# Contaminated: Chemical      7093
# Contaminated: Biological    5374
# Clean                       4916
# Name: count, dtype: int64

# %%
print ("missing values in each column")
missing_values = df.isnull().sum()
missing_values
# Out:
# missing values in each column
# source_id        0
# date             0
# description      0
# pollutant_ppm    0
# biological       0
# results          0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df['pollutant_ppm'].plot(kind='hist', bins=10)
plt.title('Pollutant Distribution (ppm)')
plt.xlabel('Pollutant PPM')
plt.ylabel('Count')
plt.show()

# %%
print ("Count records per day")
df['date'].value_counts()
# Out:
# Count records per day
# date
# 2021-06-20 11:15:00    3
# 2022-02-13 10:57:00    3
# 2022-03-18 10:49:00    3
# 2022-08-15 16:53:00    3
# 2023-06-08 13:23:00    3
#                       ..
# 2023-07-10 15:29:00    1
# 2023-07-10 15:30:00    1
# 2023-07-10 15:43:00    1
# 2023-07-10 15:46:00    1
# 2023-07-10 16:55:00    1
# Name: count, Length: 16927, dtype: int64

# %%
print ("Earliest and latest water service records")
df['date'].min(), df['date'].max()
# Out:
# Earliest and latest water service records
# (Timestamp('2021-01-04 09:17:00'), Timestamp('2023-07-10 16:55:00'))

# %%
average_bio = df['biological'].mean()
print("Average biological measurement:", average_bio)
# Out:
# Average biological measurement: 72.33525537575811

# %%
print ("Filter high pollutant levels") 
high_pollutant = df[df['pollutant_ppm'] > 50]  # change 50 to your threshold
high_pollutant
# Out:
# Filter high pollutant levels
# Empty DataFrame
# Columns: [source_id, date, description, pollutant_ppm, biological, results]
# Index: []

# %%
print ("Plot results counts")
df['results'].value_counts().plot(kind='bar')
# Out:
# Plot results counts
# <Axes: xlabel='results'>
